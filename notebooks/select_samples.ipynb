# %%
import os
import random

# %%
NU_folder_1   = "/Volumes/rsrch6/home/trans_mol_path/yuan_lab/TIER1/barretts/wsi/NU/NU_flow"
NU_folder_2   = "/Volumes/rsrch6/home/trans_mol_path/yuan_lab/TIER1/barretts/wsi/NU/NU_noFlow"
MDA_B1_folder = "/Volumes/rsrch6/home/trans_mol_path/yuan_lab/TIER1/barretts/wsi/dysplasia/wholeDataset"
MDA_B2_folder = "/Volumes/rsrch6/home/trans_mol_path/yuan_lab/TIER1/barretts/wsi/new_batch_slides/Barrett_05092024/renamedSlides"

# %%
NU_list = [os.path.join(NU_folder_1, filename) for filename in os.listdir(NU_folder_1)]
NU_list.extend([os.path.join(NU_folder_2, filename) for filename in os.listdir(NU_folder_2)])
MDA_batch1_list = [os.path.join(MDA_B1_folder, filename) for filename in os.listdir(MDA_B1_folder)]
MDA_batch2_list = [os.path.join(MDA_B2_folder, filename) for filename in os.listdir(MDA_B2_folder)]

# %%
NU_selected = random.sample(NU_list, 20)
MDA_B1_selected = random.sample(MDA_batch1_list, 15)
MDA_B2_selected = random.sample(MDA_batch2_list, 5)

# %%
qplist = NU_selected + MDA_B1_selected + MDA_B2_selected
qplist
# Out:
# ['/Volumes/rsrch6/home/trans_mol_path/yuan_lab/TIER1/barretts/wsi/NU/NU_noFlow/D1822-2021-03-24_15.28.16.ndpi',
#  '/Volumes/rsrch6/home/trans_mol_path/yuan_lab/TIER1/barretts/wsi/NU/NU_noFlow/D2029-2021-02-18_20.33.21.ndpi',
#  '/Volumes/rsrch6/home/trans_mol_path/yuan_lab/TIER1/barretts/wsi/NU/NU_flow/D1404-2021-03-10_22.10.25.ndpi',
#  '/Volumes/rsrch6/home/trans_mol_path/yuan_lab/TIER1/barretts/wsi/NU/NU_noFlow/D1065-2020-11-17_10.13.44.ndpi',
#  '/Volumes/rsrch6/home/trans_mol_path/yuan_lab/TIER1/barretts/wsi/NU/NU_noFlow/D1906-2021-03-25_19.06.31.ndpi',
#  '/Volumes/rsrch6/home/trans_mol_path/yuan_lab/TIER1/barretts/wsi/NU/NU_flow/D1974-2021-02-18_11.00.51.ndpi',
#  '/Volumes/rsrch6/home/trans_mol_path/yuan_lab/TIER1/barretts/wsi/NU/NU_noFlow/D1939-2021-02-17_11.37.29.ndpi',
#  '/Volumes/rsrch6/home/trans_mol_path/yuan_lab/TIER1/barretts/wsi/NU/NU_flow/D1436-2021-03-11_14.57.10.ndpi',
# ...
